# %% [markdown]
# # Basics of Python
# ## Experiment 2 - Python Basics and Syntax
#
# Name - Ayush Pathare
# PRN - 25070123166
# Batch - ENTC A-2

# %%
print("Hello, Welcome to Programming")
# Out:
# Hello, Welcome to Programming

# %%
a = "Hello"
print(a)
# Out:
# Hello

# %%
# Many Statements
print("Hello")
print("Today is a good day.")
print("Python is nice")
# Out:
# Hello
# Today is a good day.
# Python is nice

# %%
# One logic line
print("Hello"); print("How is coding?"); print("Coding is fun")
# Out:
# Hello
# How is coding?
# Coding is fun

# %%
# Printing Numbers
a = 3
print(a)
print(358)
print(500.200)
# Out:
# 3
# 358
# 500.2

# %%
# Variables
x = 5
y = "Hello, world!"

print(x); print(y)
# Out:
# 5
# Hello, world!

# %%
# Python is Case sensitive
a = 4
A = "Sally"

print(a); print(A)
# Out:
# 4
# Sally

# %%
# Values to multiple variables
x,y,z = "Orange", "Banana", "Cherry"
print(x,y,z)
# Out:
# Orange Banana Cherry

# %%
# Basic Arithmetic Ops
a = 10; b = 5
print("Addition =",a+b); print("Subtraction =",a-b)
print("Multiplication =",a*b); print("Division =",a/b)
# Out:
# Addition = 15
# Subtraction = 5
# Multiplication = 50
# Division = 2.0

# %%
# Understanding Data Types

x = 10
y = 3.14
z = "Python"
A = True
C = 3 + 2j

print(type(x))
print(type(y))
print(type(z))
print(type(A))
print(type(C))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>
# <class 'complex'>

# %%
# Taking Input from user

name  = input("Enter your name: ")
age   = int(input("Enter your age: "))

print("Name: ",name); print("Age: ",age)
# Out:
# Name:  Ryan
# Age:  19

# %%
# Question 1 : Take marks of 5 subjects. Find sum and average

print("Enter marks for your subjects \n")
eng = int(input("English : "))
math = int(input("Math : "))
phys = int(input("Physics : "))
chem = int(input("Chemistry : "))
bio = int(input("Biology : "))
total = eng+math+phys+chem+bio

print("Your total marks = ",total)
print("Your average marks = ",total/5)
# Out:
# Enter marks for your subjects
#
# Your total marks =  465
# Your average marks =  93.0

# %%
# Question 2 :Find area of a circle

print("To find Area of a Circle -")
r = int(input("Enter Value of Radius = "))
pi = 3.14
area = pi*r*r
print("Area of Circle = ",area)
# Out:
# To find Area of a Circle -
# Area of Circle =  78.5

# %%
# Question 3 :Find area of a rectangle

print("To find Area of a Rectangle -")
l = int(input("Enter Value of length = "))
b = int(input("Enter Value of breadth = "))

print("Area of Rectangle = ",l*b)
# Out:
# To find Area of a Rectangle -
# Area of Rectangle =  9

# %%
# Question 4 : Find perimeter of rectangle

print("To find Perimeter of Rectangle -")
l1 = int(input("Enter Value of length = "))
b1 = int(input("Enter Value of breadth = "))

print("Perimeter of Rectangle = ",l1*2+b1*2)
# Out:
# To find Perimeter of Rectangle -
# Perimeter of Rectangle =  24

# %%
# Question 5 : Simple Calculator

print("Simple Calculator")
print(" Operations : \n 1. Add \n 2. Subtract \n 3. Multiply \n 4. Divide \n")
choice = int(input("Choose Your Operation Number : "))
num1 = int(input("Enter 1st Number : "))
num2 = int(input("Enter 2nd Number : "))

match choice:

 case 1:
  print("Add : %d + %d = %d" % (num1,num2,num1+num2))

 case 2:
  print("Subtract : %d - %d = %d" % (num1,num2,num1+num2))

 case 3:
  print("Multiply : %d x %d = %d" % (num1,num2,num1*num2))

 case 4:
  print("Divide : %d / %d = %d" % (num1,num2,num1/num2))

 case _:
  print("Invalid Choice" )
# Out:
# Simple Calculator
#  Operations :
#  1. Add
#  2. Subtract
#  3. Multiply
#  4. Divide
#
# Multiply : 7 x 8 = 56
